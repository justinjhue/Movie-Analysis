# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Movie Analysis
#
# **Authors:** Justin Hue
# ***

# %% [markdown]
# ## Overview
#
# This notebook will dive into which successful films a business interested in creating original movies should look into emulating. This notebook will give insight into what genres of films are most successful, what kinds of films are the highest rated, as well as which of the top films of the last decade are the highest grossing. With this information, a business would have actionable, tangible insights that they will be able to put to use in a multitude of ways.

# %% [markdown]
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * I needed to find the films doing the best in the box and turn them into actionable insights for a company looking to get into the movie business. I chose the questions that I did based off of the data I had access to, and the solutions I thought I could provide with that information. These are important questions because they are crucial to a business finding their footing in the business.
# ***

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# * We have 2 tables from IMDB, which include basic information about each title as well as the ratings each film received, as well as the amount of votes casted to rate each film.
# * This data represents the most successful movies over a recent time period (about the last 10 years).
# * The target variable here is the average rating of the movies cross-referenced with the number of votes the films received. We want to make sure the movie was well received by a large audience.
# ***

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline
! ls
# Out:
# Movie Analysis Project Slides.pdf
# Movie-Analysis.ipynb
# README2.md
# data
# images

# %%
#importing data files, dropping duplicate data, and sorting by gross values to see what movies are making the most
df1 = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz', header=0, encoding='latin-1')
df2 = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz', header=0, encoding='latin-1')
df3 = pd.read_csv('data/zippedData/bom.movie_gross.csv.gz', header=0, encoding='latin-1')
df1.drop_duplicates()
df2.drop_duplicates()
df3.sort_values(['domestic_gross'],ascending = False).head(50)
studio_earnings = df3.groupby('studio').sum().sort_values(by = 'domestic_gross').tail(20).drop(columns='year')

# %%
#sorting values so that studios with highest domestic gross are listed first 
df3.groupby('studio').sum().sort_values(by='domestic_gross', ascending = False).head(20).drop(columns='year')
# Out:
#          domestic_gross
# studio
# BV         1.841903e+10
# Uni.       1.290239e+10
# WB         1.216805e+10
# Fox        1.094950e+10
# Sony       8.459683e+09
# Par.       7.685871e+09
# LGF        4.118963e+09
# WB (NL)    3.995700e+09
# LG/S       2.078200e+09
# P/DW       1.682900e+09
# Wein.      1.540550e+09
# SGem       1.526400e+09
# Focus      1.172041e+09
# FoxS       1.061832e+09
# TriS       9.709000e+08
# Rela.      9.432940e+08
# Sum.       9.318710e+08
# STX        7.521000e+08
# ORF        7.450000e+08
# SPC        4.420310e+08

# %% [markdown]
# Based on the table above, we learned that the top 5 grossing studios in movies are: Disney, Universal, Warner Bros., Fox, and Sony.

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created? I wanted to isolate a few key variables in the dataset: the most popular genres, studios, and highest rated movies. I removed the duplicate movies, and only used values for domestic gross, getting rid of foreign gross.
# ***

# %%
#merging all three dataframes together in order to clean data effectively
joined_df = pd.merge(df1, df2, on='tconst', how='inner')
joined_df = pd.merge(joined_df, df3, left_on=['original_title', 'start_year'],
                     right_on=['title', 'year'])
joined_df
# Out:
#          tconst                    primary_title  \
# 0     tt0315642                            Wazir
# 1     tt0337692                      On the Road
# 2     tt0359950  The Secret Life of Walter Mitty
# 3     tt0365907      A Walk Among the Tombstones
# 4     tt0369610                   Jurassic World
# ...         ...                              ...
# 1635  tt8097306                    Nobody's Fool
# 1636  tt8108198                        Andhadhun
# 1637  tt8427036                  Helicopter Eela
# 1638  tt8549902  Oolong Courtyard: KungFu School
# 1639  tt9151704        Burn the Stage: The Movie
#
#                        original_title  start_year  runtime_minutes  \
# 0                               Wazir        2016            103.0
# 1                         On the Road        2012            124.0
# 2     The Secret Life of Walter Mitty        2013            114.0
# 3         A Walk Among the Tombstones        2014            114.0
# 4                      Jurassic World        2015            124.0
# ...                               ...         ...              ...
# 1635                    Nobody's Fool        2018            110.0
# 1636                        Andhadhun        2018            139.0
# 1637                  Helicopter Eela        2018            135.0
# 1638                 Oolong Courtyard        2018            103.0
# 1639        Burn the Stage: The Movie        2018             84.0
#
#                        genres  averagerating  numvotes  \
# 0          Action,Crime,Drama            7.1     15378
# 1     Adventure,Drama,Romance            6.1     37886
# 2      Adventure,Comedy,Drama            7.3    275300
# 3          Action,Crime,Drama            6.5    105116
# 4     Action,Adventure,Sci-Fi            7.0    539338
# ...                       ...            ...       ...
# 1635     Comedy,Drama,Romance            4.6      3618
# 1636           Crime,Thriller            8.5     43409
# 1637                    Drama            5.4       673
# 1638                   Comedy            4.6        61
# 1639        Documentary,Music            8.8      2067
#
#                                 title     studio  domestic_gross  \
# 0                               Wazir    Relbig.       1100000.0
# 1                         On the Road        IFC        744000.0
# 2     The Secret Life of Walter Mitty        Fox      58200000.0
# 3         A Walk Among the Tombstones       Uni.      26300000.0
# 4                      Jurassic World       Uni.     652300000.0
# ...                               ...        ...             ...
# 1635                    Nobody's Fool       Par.      31700000.0
# 1636                        Andhadhun       Eros       1200000.0
# 1637                  Helicopter Eela       Eros         72000.0
# 1638                 Oolong Courtyard         CL         37700.0
# 1639        Burn the Stage: The Movie  Trafalgar       4200000.0
#
#      foreign_gross  year
# 0              NaN  2016
# 1          8000000  2012
# 2        129900000  2013
# 3         26900000  2014
# 4          1,019.4  2015
# ...            ...   ...
# 1635       1800000  2018
# 1636           NaN  2018
# 1637           NaN  2018
# 1638           NaN  2018
# 1639      16100000  2018
#
# [1640 rows x 13 columns]

# %%
#checking for null values
joined_df.isna().sum()
# Out:
# tconst               0
# primary_title        0
# original_title       0
# start_year           0
# runtime_minutes      4
# genres               2
# averagerating        0
# numvotes             0
# title                0
# studio               2
# domestic_gross      10
# foreign_gross      450
# year                 0
# dtype: int64

# %%
# joined_df[joined_df['runtime_minutes'].isna()]

# %%
#dropping null values in the following columns
joined_df = joined_df.dropna(subset=['runtime_minutes', 'domestic_gross', 'genres', 'studio'])

# %%
#filling null values not cleared with zeroes, dropping the foreign gross column, and rechecking null values
joined_df = joined_df.fillna(0)
joined_df = joined_df.drop(columns = 'foreign_gross')
joined_df.isna().sum()
# Out:
# tconst             0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# averagerating      0
# numvotes           0
# title              0
# studio             0
# domestic_gross     0
# year               0
# dtype: int64

# %%
#extracting separate genres
test_genre = joined_df.loc[719, 'genres']
test_genre
# Out:
# 'Action,Adventure,Sci-Fi'

# %%
#splitting on the comma to separate genres
test_genre.split(',')
# Out:
# ['Action', 'Adventure', 'Sci-Fi']

# %%
#creating a list of genres to see total of titles per genre
joined_df['genres_list'] = joined_df['genres'].map(lambda x :x.split(','))
genre_df = joined_df.explode('genres_list')
genre_df
# Out:
#          tconst                    primary_title             original_title  \
# 0     tt0315642                            Wazir                      Wazir
# 0     tt0315642                            Wazir                      Wazir
# 0     tt0315642                            Wazir                      Wazir
# 1     tt0337692                      On the Road                On the Road
# 1     tt0337692                      On the Road                On the Road
# ...         ...                              ...                        ...
# 1636  tt8108198                        Andhadhun                  Andhadhun
# 1637  tt8427036                  Helicopter Eela            Helicopter Eela
# 1638  tt8549902  Oolong Courtyard: KungFu School           Oolong Courtyard
# 1639  tt9151704        Burn the Stage: The Movie  Burn the Stage: The Movie
# 1639  tt9151704        Burn the Stage: The Movie  Burn the Stage: The Movie
#
#       start_year  runtime_minutes                   genres  averagerating  \
# 0           2016            103.0       Action,Crime,Drama            7.1
# 0           2016            103.0       Action,Crime,Drama            7.1
# 0           2016            103.0       Action,Crime,Drama            7.1
# 1           2012            124.0  Adventure,Drama,Romance            6.1
# 1           2012            124.0  Adventure,Drama,Romance            6.1
# ...          ...              ...                      ...            ...
# 1636        2018            139.0           Crime,Thriller            8.5
# 1637        2018            135.0                    Drama            5.4
# 1638        2018            103.0                   Comedy            4.6
# 1639        2018             84.0        Documentary,Music            8.8
# 1639        2018             84.0        Documentary,Music            8.8
#
#       numvotes                      title     studio  domestic_gross  year  \
# 0        15378                      Wazir    Relbig.       1100000.0  2016
# 0        15378                      Wazir    Relbig.       1100000.0  2016
# 0        15378                      Wazir    Relbig.       1100000.0  2016
# 1        37886                On the Road        IFC        744000.0  2012
# 1        37886                On the Road        IFC        744000.0  2012
# ...        ...                        ...        ...             ...   ...
# 1636     43409                  Andhadhun       Eros       1200000.0  2018
# 1637       673            Helicopter Eela       Eros         72000.0  2018
# 1638        61           Oolong Courtyard         CL         37700.0  2018
# 1639      2067  Burn the Stage: The Movie  Trafalgar       4200000.0  2018
# 1639      2067  Burn the Stage: The Movie  Trafalgar       4200000.0  2018
#
#       genres_list
# 0          Action
# 0           Crime
# 0           Drama
# 1       Adventure
# 1           Drama
# ...           ...
# 1636     Thriller
# 1637        Drama
# 1638       Comedy
# 1639  Documentary
# 1639        Music
#
# [4088 rows x 13 columns]

# %%
#making a list of top studios
top_studios = joined_df['studio'].value_counts().head(10).index
top_studios
# Out:
# Index(['Uni.', 'Fox', 'WB', 'BV', 'Par.', 'LGF', 'Sony', 'Eros', 'FoxS',
#        'IFC'],
#       dtype='object')

# %%
#shortened my joined table to only include top studios
joined_df = joined_df[joined_df['studio'].isin(top_studios)]

#creating data frames grouped by highest rating and gross with certain parameters
highest_gross = joined_df.sort_values(by='domestic_gross', ascending = False)
highest_rating = joined_df[joined_df['averagerating'] > 7.7].sort_values(('averagerating'), ascending = [False])
highest_rating = highest_rating[highest_rating['numvotes'] > 500000].sort_values(('averagerating'), ascending = [False])
highest_rating
# Out:
#          tconst                        primary_title  \
# 337   tt1375666                            Inception
# 71    tt0816692                         Interstellar
# 1362  tt4154756               Avengers: Infinity War
# 321   tt1345836                The Dark Knight Rises
# 17    tt0435761                          Toy Story 3
# 120   tt0993846              The Wolf of Wall Street
# 862   tt2096673                           Inside Out
# 826   tt2015381              Guardians of the Galaxy
# 352   tt1392214                            Prisoners
# 170   tt1130884                       Shutter Island
# 350   tt1392190                   Mad Max: Fury Road
# 836   tt2024544                     12 Years a Slave
# 947   tt2267998                            Gone Girl
# 953   tt2278388             The Grand Budapest Hotel
# 1278  tt3659388                          The Martian
# 393   tt1431045                             Deadpool
# 102   tt0947798                           Black Swan
# 753   tt1877832           X-Men: Days of Future Past
# 612   tt1663202                         The Revenant
# 576   tt1631867                     Edge of Tomorrow
# 22    tt0454876                           Life of Pi
# 1070  tt2543164                              Arrival
# 153   tt1074638                              Skyfall
# 1248  tt3498820           Captain America: Civil War
# 731   tt1843866  Captain America: The Winter Soldier
#
#                            original_title  start_year  runtime_minutes  \
# 337                             Inception        2010            148.0
# 71                           Interstellar        2014            169.0
# 1362               Avengers: Infinity War        2018            149.0
# 321                 The Dark Knight Rises        2012            164.0
# 17                            Toy Story 3        2010            103.0
# 120               The Wolf of Wall Street        2013            180.0
# 862                            Inside Out        2015             95.0
# 826               Guardians of the Galaxy        2014            121.0
# 352                             Prisoners        2013            153.0
# 170                        Shutter Island        2010            138.0
# 350                    Mad Max: Fury Road        2015            120.0
# 836                      12 Years a Slave        2013            134.0
# 947                             Gone Girl        2014            149.0
# 953              The Grand Budapest Hotel        2014             99.0
# 1278                          The Martian        2015            144.0
# 393                              Deadpool        2016            108.0
# 102                            Black Swan        2010            108.0
# 753            X-Men: Days of Future Past        2014            132.0
# 612                          The Revenant        2015            156.0
# 576                      Edge of Tomorrow        2014            113.0
# 22                             Life of Pi        2012            127.0
# 1070                              Arrival        2016            116.0
# 153                               Skyfall        2012            143.0
# 1248           Captain America: Civil War        2016            147.0
# 731   Captain America: The Winter Soldier        2014            136.0
#
#                           genres  averagerating  numvotes  \
# 337      Action,Adventure,Sci-Fi            8.8   1841066
# 71        Adventure,Drama,Sci-Fi            8.6   1299334
# 1362     Action,Adventure,Sci-Fi            8.5    670926
# 321              Action,Thriller            8.4   1387769
# 17    Adventure,Animation,Comedy            8.3    682218
# 120        Biography,Crime,Drama            8.2   1035358
# 862   Adventure,Animation,Comedy            8.2    536181
# 826      Action,Adventure,Comedy            8.1    948394
# 352          Crime,Drama,Mystery            8.1    526273
# 170             Mystery,Thriller            8.1   1005960
# 350      Action,Adventure,Sci-Fi            8.1    780910
# 836      Biography,Drama,History            8.1    577301
# 947       Drama,Mystery,Thriller            8.1    761592
# 953       Adventure,Comedy,Crime            8.1    633604
# 1278      Adventure,Drama,Sci-Fi            8.0    680116
# 393      Action,Adventure,Comedy            8.0    820847
# 102               Drama,Thriller            8.0    648854
# 753      Action,Adventure,Sci-Fi            8.0    620079
# 612   Action,Adventure,Biography            8.0    621193
# 576                Action,Sci-Fi            7.9    546284
# 22       Adventure,Drama,Fantasy            7.9    535836
# 1070        Drama,Mystery,Sci-Fi            7.9    515483
# 153    Action,Adventure,Thriller            7.8    592221
# 1248     Action,Adventure,Sci-Fi            7.8    583507
# 731      Action,Adventure,Sci-Fi            7.8    666252
#
#                                     title studio  domestic_gross  year  \
# 337                             Inception     WB     292600000.0  2010
# 71                           Interstellar   Par.     188000000.0  2014
# 1362               Avengers: Infinity War     BV     678800000.0  2018
# 321                 The Dark Knight Rises     WB     448100000.0  2012
# 17                            Toy Story 3     BV     415000000.0  2010
# 120               The Wolf of Wall Street   Par.     116900000.0  2013
# 862                            Inside Out     BV     356500000.0  2015
# 826               Guardians of the Galaxy     BV     333200000.0  2014
# 352                             Prisoners     WB      61000000.0  2013
# 170                        Shutter Island   Par.     128000000.0  2010
# 350                    Mad Max: Fury Road     WB     153600000.0  2015
# 836                      12 Years a Slave   FoxS      56700000.0  2013
# 947                             Gone Girl    Fox     167800000.0  2014
# 953              The Grand Budapest Hotel   FoxS      59300000.0  2014
# 1278                          The Martian    Fox     228400000.0  2015
# 393                              Deadpool    Fox     363100000.0  2016
# 102                            Black Swan   FoxS     107000000.0  2010
# 753            X-Men: Days of Future Past    Fox     233900000.0  2014
# 612                          The Revenant    Fox     183600000.0  2015
# 576                      Edge of Tomorrow     WB     100200000.0  2014
# 22                             Life of Pi    Fox     125000000.0  2012
# 1070                              Arrival   Par.     100500000.0  2016
# 153                               Skyfall   Sony     304400000.0  2012
# 1248           Captain America: Civil War     BV     408100000.0  2016
# 731   Captain America: The Winter Soldier     BV     259800000.0  2014
#
#                          genres_list
# 337      [Action, Adventure, Sci-Fi]
# 71        [Adventure, Drama, Sci-Fi]
# 1362     [Action, Adventure, Sci-Fi]
# 321               [Action, Thriller]
# 17    [Adventure, Animation, Comedy]
# 120        [Biography, Crime, Drama]
# 862   [Adventure, Animation, Comedy]
# 826      [Action, Adventure, Comedy]
# 352          [Crime, Drama, Mystery]
# 170              [Mystery, Thriller]
# 350      [Action, Adventure, Sci-Fi]
# 836      [Biography, Drama, History]
# 947       [Drama, Mystery, Thriller]
# 953       [Adventure, Comedy, Crime]
# 1278      [Adventure, Drama, Sci-Fi]
# 393      [Action, Adventure, Comedy]
# 102                [Drama, Thriller]
# 753      [Action, Adventure, Sci-Fi]
# 612   [Action, Adventure, Biography]
# 576                 [Action, Sci-Fi]
# 22       [Adventure, Drama, Fantasy]
# 1070        [Drama, Mystery, Sci-Fi]
# 153    [Action, Adventure, Thriller]
# 1248     [Action, Adventure, Sci-Fi]
# 731      [Action, Adventure, Sci-Fi]

# %%
# # Here you run your code to clean the data
# df1.drop_duplicates()
# df2.drop_duplicates()
# joined_df = pd.merge(df1, df2, on='tconst', how='inner') #These two tables are merged by common id number.
# joined_df.sort_values((['numvotes', 'averagerating']), ascending=[False, False]).head(50) #This code sorts by the number of votes casted
# joined_df = joined_df[joined_df['numvotes'] > 500000].sort_values(('numvotes'), ascending = [False]) 
# #in order to filter down the number of movies, i implemented code that only shows movies with over 500,000 votes. source: https://stackoverflow.com/questions/13851535/how-to-delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression

# joined_df = joined_df[joined_df['averagerating'] > 7.5].sort_values(('averagerating'), ascending = [False])
# joined_df = joined_df.head(20)
# joined_df = joined_df.drop(columns = ['tconst', 'start_year', 'runtime_minutes', 'original_title'])
# joined_df

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
#gross by studio
sns.barplot(data = joined_df, x='studio', y='domestic_gross');
plt.xlabel('studio')
plt.ylabel('Gross')
plt.title('Gross by Studio', size=24);

# %%
#gross by genre
sns.barplot(data = genre_df, y='genres_list', x='domestic_gross');
plt.xlabel('Gross')
plt.ylabel('Genre')
plt.title('Gross by Genre', size=24);

# %%
#plot to show ratings of titles
sns.barplot(data = highest_rating, y='original_title', x='averagerating');
plt.xlabel('Rating')
plt.ylabel('Title')
plt.title('Top Movie Ratings', size=24);

# %%
#This was code used to create a bar and line graph that overlapped, but proved to not be complterely useful
# fig, ax1 = plt.subplots(figsize=(10,6))
# ax1.set_title('Ratings x Gross', fontsize=16)
# ax1.set_xlabel('Rating', fontsize=16)
# ax1.set_ylabel('Movies', fontsize=16)
# ax2 = sns.barplot(y='original_title', x='averagerating', data = highest_rating,)
# ax1.tick_params(axis='x')
# ax2 = ax1.twiny()
# color = 'tab:red'
# ax2.set_ylabel('Domestic Gross', fontsize=16, color=color)
# ax2 = sns.lineplot(y='original_title', x='domestic_gross', data = highest_rating, sort=False)
# ax2.tick_params(axis='y')
# plt.show()
#source https://towardsdatascience.com/combo-charts-with-seaborn-and-python-2bc911a08950

# %%
#created to show the correlation between gross and rating.
fig3 = sns.scatterplot(data=highest_rating, x='domestic_gross', y='averagerating');
plt.xlabel('Gross')
plt.ylabel('Rating')
plt.title('Correlation of Gross and Rating', size=24);

# %% [markdown]
# ## Evaluation
# Evaluate how well your work solves the stated business problem.
#
# ***
# - I personally believe these results yield actionable information that can be used to get a foot into the movie business as a major player.
#
# ***

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - Out of the top 10 studios, Disney(BV) makes the most domestic gross on average.
# - I recommend Microsoft mimic Disney's business practices as much as possible. This includes collaborating with the actors, directors, and producers a part of their most successful titles.
# - Out of the list of genres, Animation, Sci-Fi, and Adventure make up the greatest revenue across all titles collectively. If the end goal is maximum gross, I recommend creating titles in, at minimum, one of these three genres.

# %% [markdown]
# - My analysis may not completely solve the business problems because there are multiple additional factors not completely taken into account, such as budget size, which cast and crew generate the most revenue consistently, which months are most popular for movies, as well as the fact that my data is mainly from one source, which most greatly impacts the reviews.
#
# - In order to improve this project in the future, I could use more data from more sources to create a greater pool of information used to answer more questions and give more suggestions.
